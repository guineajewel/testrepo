# %%
#load the SQL extension and establish a connection with the DB2 database
# %load_ext sql

# %%
# Connection string for my Db2 on Cloud database instance below
# %sql ibm_db_sa://pcx39744:5TxZYdKaZRW3fKyo@ba99a9e6-d59e-4883-8fc0-d6a8c9f7a08f.c1ogj3sd0tgtu0lqde00.databases.appdomain.cloud:31321/BLUDB?security=SSL
# Out:
# 'Connected: pcx39744@BLUDB'

# %%
#Problem 1: Find the total number of crimes recorded in the CRIME table.
# %sql select count(*) from CHICAGO_CRIME_DATA
# Out:
#  * ibm_db_sa://pcx39744:***@ba99a9e6-d59e-4883-8fc0-d6a8c9f7a08f.c1ogj3sd0tgtu0lqde00.databases.appdomain.cloud:31321/BLUDB
# Done.
# [(533,)]

# %%
# Problem 2: List community areas with per capita income less than 11000.
# %sql select count(*) from CHICAGO_PUBLIC_SCHOOLS
# Out:
#  * ibm_db_sa://pcx39744:***@ba99a9e6-d59e-4883-8fc0-d6a8c9f7a08f.c1ogj3sd0tgtu0lqde00.databases.appdomain.cloud:31321/BLUDB
# Done.
# [(566,)]

# %%
# %sql select count(*) from CENSUS_DATA
# Out:
#  * ibm_db_sa://pcx39744:***@ba99a9e6-d59e-4883-8fc0-d6a8c9f7a08f.c1ogj3sd0tgtu0lqde00.databases.appdomain.cloud:31321/BLUDB
# Done.
# [(78,)]

# %%
# %sql select COLNAME, TYPENAME, LENGTH from SYSCAT.COLUMNS where TABNAME = 'CENSUS_DATA'
# Out:
#  * ibm_db_sa://pcx39744:***@ba99a9e6-d59e-4883-8fc0-d6a8c9f7a08f.c1ogj3sd0tgtu0lqde00.databases.appdomain.cloud:31321/BLUDB
# Done.
# [('COLUMN_0', 'SMALLINT', 2),
#  ('COLUMN_1', 'VARCHAR', 22),
#  ('COLUMN_2', 'DECIMAL', 4),
#  ('COLUMN_3', 'DECIMAL', 4),
#  ('COLUMN_4', 'DECIMAL', 4),
#  ('COLUMN_5', 'DECIMAL', 4),
#  ('COLUMN_6', 'DECIMAL', 4),
#  ('COLUMN_7', 'INTEGER', 4),
#  ('COLUMN_8', 'SMALLINT', 2),
#  ('COMMUNITY_AREA_NUMBER', 'SMALLINT', 2),
#  ('COMMUNITY_AREA_NAME', 'VARCHAR', 22),
#  ('PERCENT_OF_HOUSING_CROWDED', 'DECIMAL', 4),
#  ('PERCENT_HOUSEHOLDS_BELOW_POVERTY', 'DECIMAL', 4),
#  ('PERCENT_AGED_16__UNEMPLOYED', 'DECIMAL', 4),
#  ('PERCENT_AGED_25__WITHOUT_HIGH_SCHOOL_DIPLOMA', 'DECIMAL', 4),
#  ('PERCENT_AGED_UNDER_18_OR_OVER_64', 'DECIMAL', 4),
#  ('PER_CAPITA_INCOME', 'INTEGER', 4),
#  ('HARDSHIP_INDEX', 'SMALLINT', 2),
#  ('COMUNITY_AREA_NUMBER', 'INTEGER', 4),
#  ('COMUNITY_AREA_NAME', 'VARCHAR', 255),
#  ('PERCENT_OF_HOUSING_CROWDED', 'DOUBLE', 8),
# ...

# %%
# %sql select COLNAME, TYPENAME, LENGTH from SYSCAT.COLUMNS where TABNAME = 'CHICAGO_SCHOOLS_DATA'
# Out:
#  * ibm_db_sa://pcx39744:***@ba99a9e6-d59e-4883-8fc0-d6a8c9f7a08f.c1ogj3sd0tgtu0lqde00.databases.appdomain.cloud:31321/BLUDB
# Done.
# [('PARENT_ENVIRONMENT_ICON', 'VARCHAR', 7),
#  ('PARENT_ENVIRONMENT_SCORE', 'VARCHAR', 3),
#  ('AVERAGE_STUDENT_ATTENDANCE', 'VARCHAR', 6),
#  ('RATE_OF_MISCONDUCTS__PER_100_STUDENTS_', 'DECIMAL', 5),
#  ('AVERAGE_TEACHER_ATTENDANCE', 'VARCHAR', 6),
#  ('INDIVIDUALIZED_EDUCATION_PROGRAM_COMPLIANCE_RATE', 'VARCHAR', 7),
#  ('PK_2_LITERACY__', 'VARCHAR', 4),
#  ('PK_2_MATH__', 'VARCHAR', 4),
#  ('GR3_5_GRADE_LEVEL_MATH__', 'VARCHAR', 4),
#  ('GR3_5_GRADE_LEVEL_READ__', 'VARCHAR', 4),
#  ('GR3_5_KEEP_PACE_READ__', 'VARCHAR', 4),
#  ('GR3_5_KEEP_PACE_MATH__', 'VARCHAR', 4),
#  ('GR6_8_GRADE_LEVEL_MATH__', 'VARCHAR', 4),
#  ('GR6_8_GRADE_LEVEL_READ__', 'VARCHAR', 4),
#  ('GR6_8_KEEP_PACE_MATH_', 'VARCHAR', 4),
#  ('GR6_8_KEEP_PACE_READ__', 'VARCHAR', 4),
#  ('GR_8_EXPLORE_MATH__', 'VARCHAR', 4),
#  ('GR_8_EXPLORE_READ__', 'VARCHAR', 4),
# ...

# %%
# %sql select count(*) from CHICAGO_SOCIOECONOMIC_DATA
# Out:
#  * ibm_db_sa://pcx39744:***@ba99a9e6-d59e-4883-8fc0-d6a8c9f7a08f.c1ogj3sd0tgtu0lqde00.databases.appdomain.cloud:31321/BLUDB
# Done.
# [(78,)]

# %%
# %sql select COLNAME, TYPENAME, LENGTH from SYSCAT.COLUMNS where TABNAME = 'CHICAGO_CRIME_DATA'
# Out:
#  * ibm_db_sa://pcx39744:***@ba99a9e6-d59e-4883-8fc0-d6a8c9f7a08f.c1ogj3sd0tgtu0lqde00.databases.appdomain.cloud:31321/BLUDB
# Done.
# [('ID', 'INTEGER', 4),
#  ('CASE_NUMBER', 'VARCHAR', 8),
#  ('DATE', 'DATE', 4),
#  ('LOCATION_DESCRIPTION', 'VARCHAR', 33),
#  ('COLUMN_0', 'INTEGER', 4),
#  ('COLUMN_1', 'VARCHAR', 8),
#  ('COLUMN_2', 'DATE', 4),
#  ('COLUMN_3', 'VARCHAR', 35),
#  ('COLUMN_4', 'VARCHAR', 4),
#  ('COLUMN_5', 'VARCHAR', 15),
#  ('COLUMN_6', 'VARCHAR', 46),
#  ('COLUMN_7', 'VARCHAR', 33),
#  ('COLUMN_8', 'VARCHAR', 5),
#  ('COLUMN_9', 'VARCHAR', 5),
#  ('COLUMN_10', 'SMALLINT', 2),
#  ('COLUMN_11', 'SMALLINT', 2),
#  ('COLUMN_12', 'SMALLINT', 2),
#  ('COLUMN_13', 'SMALLINT', 2),
#  ('COLUMN_14', 'VARCHAR', 3),
#  ('COLUMN_15', 'INTEGER', 4),
#  ('COLUMN_16', 'INTEGER', 4),
#  ('COLUMN_17', 'SMALLINT', 2),
#  ('COLUMN_18', 'DECIMAL', 18),
#  ('COLUMN_19', 'DECIMAL', 18),
#  ('COLUMN_20', 'VARCHAR', 29),
#  ('ID', 'INTEGER', 4),
#  ('CASE_NUMBER', 'VARCHAR', 8),
# ...

# %%
#Problem 2: List community areas with per capita income less than 11000.
# %sql SELECT community_area_name, per_capita_income FROM CENSUS_DATA where per_capita_income <11000
# Out:
#  * ibm_db_sa://pcx39744:***@ba99a9e6-d59e-4883-8fc0-d6a8c9f7a08f.c1ogj3sd0tgtu0lqde00.databases.appdomain.cloud:31321/BLUDB
# Done.
# [('West Garfield Park', 10934),
#  ('South Lawndale', 10402),
#  ('Fuller Park', 10432),
#  ('Riverdale', 8201)]

# %%
#Problem 3: List all case numbers for crimes involving minors?
# %sql select CASE_NUMBER,PRIMARY_TYPE,DESCRIPTION from CHICAGO_CRIME_DATA WHERE DESCRIPTION like '%MINOR%' or PRIMARY_TYPE LIKE '%MINOR%'
# Out:
#  * ibm_db_sa://pcx39744:***@ba99a9e6-d59e-4883-8fc0-d6a8c9f7a08f.c1ogj3sd0tgtu0lqde00.databases.appdomain.cloud:31321/BLUDB
# Done.
# [('HL266884', 'LIQUOR LAW VIOL', 'SELL/GIVE/DEL LIQUOR TO MINOR'),
#  ('HK238408', 'LIQUOR LAW VIOL', 'ILLEGAL CONSUMPTION BY MINOR')]

# %%
#Problem 4: List all kidnapping crimes involving a child?(children are not considered minors for the purposes of crime analysis)
# %sql select * from CHICAGO_CRIME_DATA where PRIMARY_TYPE = 'KIDNAPPING' AND DESCRIPTION LIKE '%CHILD%'
# Out:
#  * ibm_db_sa://pcx39744:***@ba99a9e6-d59e-4883-8fc0-d6a8c9f7a08f.c1ogj3sd0tgtu0lqde00.databases.appdomain.cloud:31321/BLUDB
# Done.
# [(5276766, 'HN144152', datetime.date(2007, 1, 26), '050XX W VAN BUREN ST', '1792', 'KIDNAPPING', 'CHILD ABDUCTION/STRANGER', 'STREET', 'FALSE', 'FALSE', 1533, 15, 29, 25, '20', 1143050, 1897546, 2007, Decimal('41.87490841'), Decimal('-87.75024931'), '(41.874908413, -87.750249307)')]

# %%
#Problem 5: What kind of crimes were recorded at schools?
# %sql select DISTINCT(PRIMARY_TYPE) FROM CHICAGO_CRIME_DATA WHERE LOCATION_DESCRIPTION LIKE '%SCHOOL%'
# Out:
#  * ibm_db_sa://pcx39744:***@ba99a9e6-d59e-4883-8fc0-d6a8c9f7a08f.c1ogj3sd0tgtu0lqde00.databases.appdomain.cloud:31321/BLUDB
# Done.
# [('ASSAULT',),
#  ('BATTERY',),
#  ('CRIMINAL DAMAGE',),
#  ('CRIMINAL TRESPA',),
#  ('NARCOTICS',),
#  ('PUBLIC PEACE VI',)]

# %%
#Problem 6: List the average safety score for all types of schools.
# %sql select "Elementary, Middle, or High School", avg(SAFETY_SCORE) as average_safety_score from CHICAGO_PUBLIC_SCHOOLS GROUP BY "Elementary, Middle, or High School"
# Out:
#  * ibm_db_sa://pcx39744:***@ba99a9e6-d59e-4883-8fc0-d6a8c9f7a08f.c1ogj3sd0tgtu0lqde00.databases.appdomain.cloud:31321/BLUDB
# Done.
# [('ES', 49), ('HS', 49), ('MS', 48)]

# %%
#Problem 7: List 5 community areas with highest % of households below poverty line.
# %sql select COMMUNITY_AREA_NAME,PERCENT_HOUSEHOLDS_BELOW_POVERTY from CENSUS_DATA ORDER BY PERCENT_HOUSEHOLDS_BELOW_POVERTY DESC LIMIT 5
# Out:
#  * ibm_db_sa://pcx39744:***@ba99a9e6-d59e-4883-8fc0-d6a8c9f7a08f.c1ogj3sd0tgtu0lqde00.databases.appdomain.cloud:31321/BLUDB
# Done.
# [('Riverdale', Decimal('56.5')),
#  ('Fuller Park', Decimal('51.2')),
#  ('Englewood', Decimal('46.6')),
#  ('North Lawndale', Decimal('43.1')),
#  ('East Garfield Park', Decimal('42.4'))]

# %%
#Problem 8: Which community area(number) is most crime prone?
# %%sql 
SELECT COMMUNITY_AREA_NUMBER from CHICAGO_CRIME_DATA  
group by COMMUNITY_AREA_NUMBER order by COUNT(*) DESC NULLS LAST 
LIMIT 1
# Out:
#  * ibm_db_sa://pcx39744:***@ba99a9e6-d59e-4883-8fc0-d6a8c9f7a08f.c1ogj3sd0tgtu0lqde00.databases.appdomain.cloud:31321/BLUDB
# Done.
# [(25,)]

# %%
#Problem 9: Use a sub-query to find the name of the community area with highest hardship index.
# %%sql
select COMMUNITY_AREA_NAME from CENSUS_DATA where HARDSHIP_INDEX = (SELECT max(HARDSHIP_INDEX) from CENSUS_DATA)
# Out:
#  * ibm_db_sa://pcx39744:***@ba99a9e6-d59e-4883-8fc0-d6a8c9f7a08f.c1ogj3sd0tgtu0lqde00.databases.appdomain.cloud:31321/BLUDB
# Done.
# [('Riverdale',)]

# %%
#Problem 10: Use a sub-query to determine the Community Area Name with most number of crimes?
# %%sql 
SELECT COMMUNITY_AREA_NAME FROM CENSUS_DATA WHERE COMMUNITY_AREA_NUMBER IN (SELECT COMMUNITY_AREA_NUMBER from CHICAGO_CRIME_DATA  
group by COMMUNITY_AREA_NUMBER order by COUNT(*) DESC 
LIMIT 1)
# Out:
#  * ibm_db_sa://pcx39744:***@ba99a9e6-d59e-4883-8fc0-d6a8c9f7a08f.c1ogj3sd0tgtu0lqde00.databases.appdomain.cloud:31321/BLUDB
# Done.
# [('Austin',)]
